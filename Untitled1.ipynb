# %%
import pycuda.driver as cuda
from facenet_config import InceptionResnetV1, fixed_image_standardization
from facenet_capstone.utils import training
# from utils.logits import CosFace
import torch
from torch.utils.data import DataLoader, SubsetRandomSampler
from torch.optim import lr_scheduler
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms
import torch.optim as optim
import numpy as np
import os
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

# Determine if an nvidia GPU is available
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# For reproducibility, Seed the RNG for all devices (both CPU and CUDA):
torch.manual_seed(0)
torch.cuda.manual_seed_all(0)
# np.random.seed(0)
# random.seed(0)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print('\n***** *****\n')
print('Running on device: {}'.format(device)) 

# ***** *****

# Set training parameters
batch_size = 32
epochs = 40
workers = 0 if os.name == 'nt' else 8 #nt for Windows
print(workers)
# Out:
# ***** *****
#
# Running on device: cuda:0
# 0

# %%
# Locate training and testing folders
train_dir = 'D:/TinyFace_Closed/train'
test_dir = 'D:/TinyFace_Closed/test'

train_trans = transforms.Compose( [ transforms.Resize((160,160)),
                                    transforms.RandomHorizontalFlip(p=0.6), 
                                    np.float32, transforms.ToTensor(), fixed_image_standardization ] )

test_trans = transforms.Compose( [ transforms.Resize((160,160)),
                                    # transforms.RandomHorizontalFlip(p=0.6), 
                                    np.float32, transforms.ToTensor(), fixed_image_standardization ] )

train_set = datasets.ImageFolder(train_dir, transform = train_trans)
test_set = datasets.ImageFolder(test_dir, transform = test_trans)

train_loader = torch.utils.data.DataLoader(train_set, batch_size = batch_size, shuffle = True, num_workers = workers)
test_loader = torch.utils.data.DataLoader(test_set, batch_size = batch_size, shuffle = False, num_workers = workers)

assert(train_set.class_to_idx.items() == test_set.class_to_idx.items()) #assertionError if !=

class_names = train_set.classes

# %%
#################
path_weight = 'C:/Users/DS/Yonsei_Capstone/save_model/resnet_1.pt'
path_all = 'C:/Users/DS/Yonsei_Capstone/save_model/resnet.tar'
resnet = torch.load(path_all)
#resnet = InceptionResnetV1(pretrained = 'vggface2', classify=True, num_classes=len(class_names))
#resnet.load_state_dict(torch.load(path_weight))

# %%
resnet.to(device)

# print(resnet)
# print(len(class_names))

# ***** *****

# Resnet : Determine parameters to be freezed, or unfreezed
# Retrain only logit >>> softmax classifier
for name, param in resnet.named_parameters():
    param.requires_grad = True
        
# Resnet : Display all learnable parameters
print()
print('Learnable Paramater List')
print('-' *24)
print()

for name, param in resnet.named_parameters():
    if param.requires_grad:
        print('resnet\t:', name)
# Out:
# Learnable Paramater List
# ------------------------
#
# resnet	: conv2d_1a.conv.weight
# resnet	: conv2d_1a.bn.weight
# resnet	: conv2d_1a.bn.bias
# resnet	: conv2d_2a.conv.weight
# resnet	: conv2d_2a.bn.weight
# resnet	: conv2d_2a.bn.bias
# resnet	: conv2d_2b.conv.weight
# resnet	: conv2d_2b.bn.weight
# resnet	: conv2d_2b.bn.bias
# resnet	: conv2d_3b.conv.weight
# resnet	: conv2d_3b.bn.weight
# resnet	: conv2d_3b.bn.bias
# resnet	: conv2d_4a.conv.weight
# resnet	: conv2d_4a.bn.weight
# resnet	: conv2d_4a.bn.bias
# resnet	: conv2d_4b.conv.weight
# resnet	: conv2d_4b.bn.weight
# resnet	: conv2d_4b.bn.bias
# resnet	: repeat_1.0.branch0.conv.weight
# resnet	: repeat_1.0.branch0.bn.weight
# resnet	: repeat_1.0.branch0.bn.bias
# resnet	: repeat_1.0.branch1.0.conv.weight
# resnet	: repeat_1.0.branch1.0.bn.weight
# resnet	: repeat_1.0.branch1.0.bn.bias
# resnet	: repeat_1.0.branch1.1.conv.weight
# resnet	: repeat_1.0.branch1.1.bn.weight
# resnet	: repeat_1.0.branch1.1.bn.bias
# resnet	: repeat_1.0.branch2.0.conv.weight
# resnet	: repeat_1.0.branch2.0.bn.weight
# resnet	: repeat_1.0.branch2.0.bn.bias
# resnet	: repeat_1.0.branch2.1.conv.weight
# resnet	: repeat_1.0.branch2.1.bn.weight
# resnet	: repeat_1.0.branch2.1.bn.bias
# resnet	: repeat_1.0.branch2.2.conv.weight
# resnet	: repeat_1.0.branch2.2.bn.weight
# resnet	: repeat_1.0.branch2.2.bn.bias
# resnet	: repeat_1.0.conv2d.weight
# resnet	: repeat_1.0.conv2d.bias
# resnet	: repeat_1.1.branch0.conv.weight
# resnet	: repeat_1.1.branch0.bn.weight
# resnet	: repeat_1.1.branch0.bn.bias
# resnet	: repeat_1.1.branch1.0.conv.weight
# resnet	: repeat_1.1.branch1.0.bn.weight
# resnet	: repeat_1.1.branch1.0.bn.bias
# resnet	: repeat_1.1.branch1.1.conv.weight
# resnet	: repeat_1.1.branch1.1.bn.weight
# resnet	: repeat_1.1.branch1.1.bn.bias
# resnet	: repeat_1.1.branch2.0.conv.weight
# resnet	: repeat_1.1.branch2.0.bn.weight
# resnet	: repeat_1.1.branch2.0.bn.bias
# resnet	: repeat_1.1.branch2.1.conv.weight
# resnet	: repeat_1.1.branch2.1.bn.weight
# resnet	: repeat_1.1.branch2.1.bn.bias
# resnet	: repeat_1.1.branch2.2.conv.weight
# resnet	: repeat_1.1.branch2.2.bn.weight
# resnet	: repeat_1.1.branch2.2.bn.bias
# resnet	: repeat_1.1.conv2d.weight
# resnet	: repeat_1.1.conv2d.bias
# resnet	: repeat_1.2.branch0.conv.weight
# resnet	: repeat_1.2.branch0.bn.weight
# resnet	: repeat_1.2.branch0.bn.bias
# resnet	: repeat_1.2.branch1.0.conv.weight
# resnet	: repeat_1.2.branch1.0.bn.weight
# resnet	: repeat_1.2.branch1.0.bn.bias
# resnet	: repeat_1.2.branch1.1.conv.weight
# resnet	: repeat_1.2.branch1.1.bn.weight
# resnet	: repeat_1.2.branch1.1.bn.bias
# resnet	: repeat_1.2.branch2.0.conv.weight
# resnet	: repeat_1.2.branch2.0.bn.weight
# resnet	: repeat_1.2.branch2.0.bn.bias
# resnet	: repeat_1.2.branch2.1.conv.weight
# resnet	: repeat_1.2.branch2.1.bn.weight
# resnet	: repeat_1.2.branch2.1.bn.bias
# resnet	: repeat_1.2.branch2.2.conv.weight
# resnet	: repeat_1.2.branch2.2.bn.weight
# resnet	: repeat_1.2.branch2.2.bn.bias
# resnet	: repeat_1.2.conv2d.weight
# resnet	: repeat_1.2.conv2d.bias
# resnet	: repeat_1.3.branch0.conv.weight
# resnet	: repeat_1.3.branch0.bn.weight
# resnet	: repeat_1.3.branch0.bn.bias
# resnet	: repeat_1.3.branch1.0.conv.weight
# resnet	: repeat_1.3.branch1.0.bn.weight
# resnet	: repeat_1.3.branch1.0.bn.bias
# resnet	: repeat_1.3.branch1.1.conv.weight
# resnet	: repeat_1.3.branch1.1.bn.weight
# resnet	: repeat_1.3.branch1.1.bn.bias
# resnet	: repeat_1.3.branch2.0.conv.weight
# resnet	: repeat_1.3.branch2.0.bn.weight
# resnet	: repeat_1.3.branch2.0.bn.bias
# resnet	: repeat_1.3.branch2.1.conv.weight
# resnet	: repeat_1.3.branch2.1.bn.weight
# resnet	: repeat_1.3.branch2.1.bn.bias
# resnet	: repeat_1.3.branch2.2.conv.weight
# resnet	: repeat_1.3.branch2.2.bn.weight
# resnet	: repeat_1.3.branch2.2.bn.bias
# resnet	: repeat_1.3.conv2d.weight
# resnet	: repeat_1.3.conv2d.bias
# resnet	: repeat_1.4.branch0.conv.weight
# resnet	: repeat_1.4.branch0.bn.weight
# resnet	: repeat_1.4.branch0.bn.bias
# resnet	: repeat_1.4.branch1.0.conv.weight
# resnet	: repeat_1.4.branch1.0.bn.weight
# resnet	: repeat_1.4.branch1.0.bn.bias
# resnet	: repeat_1.4.branch1.1.conv.weight
# resnet	: repeat_1.4.branch1.1.bn.weight
# resnet	: repeat_1.4.branch1.1.bn.bias
# resnet	: repeat_1.4.branch2.0.conv.weight
# resnet	: repeat_1.4.branch2.0.bn.weight
# resnet	: repeat_1.4.branch2.0.bn.bias
# resnet	: repeat_1.4.branch2.1.conv.weight
# resnet	: repeat_1.4.branch2.1.bn.weight
# resnet	: repeat_1.4.branch2.1.bn.bias
# resnet	: repeat_1.4.branch2.2.conv.weight
# resnet	: repeat_1.4.branch2.2.bn.weight
# resnet	: repeat_1.4.branch2.2.bn.bias
# resnet	: repeat_1.4.conv2d.weight
# resnet	: repeat_1.4.conv2d.bias
# resnet	: mixed_6a.branch0.conv.weight
# resnet	: mixed_6a.branch0.bn.weight
# resnet	: mixed_6a.branch0.bn.bias
# resnet	: mixed_6a.branch1.0.conv.weight
# resnet	: mixed_6a.branch1.0.bn.weight
# resnet	: mixed_6a.branch1.0.bn.bias
# resnet	: mixed_6a.branch1.1.conv.weight
# resnet	: mixed_6a.branch1.1.bn.weight
# resnet	: mixed_6a.branch1.1.bn.bias
# resnet	: mixed_6a.branch1.2.conv.weight
# resnet	: mixed_6a.branch1.2.bn.weight
# resnet	: mixed_6a.branch1.2.bn.bias
# resnet	: repeat_2.0.branch0.conv.weight
# resnet	: repeat_2.0.branch0.bn.weight
# resnet	: repeat_2.0.branch0.bn.bias
# resnet	: repeat_2.0.branch1.0.conv.weight
# resnet	: repeat_2.0.branch1.0.bn.weight
# resnet	: repeat_2.0.branch1.0.bn.bias
# resnet	: repeat_2.0.branch1.1.conv.weight
# resnet	: repeat_2.0.branch1.1.bn.weight
# resnet	: repeat_2.0.branch1.1.bn.bias
# resnet	: repeat_2.0.branch1.2.conv.weight
# resnet	: repeat_2.0.branch1.2.bn.weight
# resnet	: repeat_2.0.branch1.2.bn.bias
# resnet	: repeat_2.0.conv2d.weight
# resnet	: repeat_2.0.conv2d.bias
# resnet	: repeat_2.1.branch0.conv.weight
# resnet	: repeat_2.1.branch0.bn.weight
# resnet	: repeat_2.1.branch0.bn.bias
# resnet	: repeat_2.1.branch1.0.conv.weight
# resnet	: repeat_2.1.branch1.0.bn.weight
# resnet	: repeat_2.1.branch1.0.bn.bias
# resnet	: repeat_2.1.branch1.1.conv.weight
# resnet	: repeat_2.1.branch1.1.bn.weight
# resnet	: repeat_2.1.branch1.1.bn.bias
# resnet	: repeat_2.1.branch1.2.conv.weight
# resnet	: repeat_2.1.branch1.2.bn.weight
# resnet	: repeat_2.1.branch1.2.bn.bias
# resnet	: repeat_2.1.conv2d.weight
# resnet	: repeat_2.1.conv2d.bias
# resnet	: repeat_2.2.branch0.conv.weight
# resnet	: repeat_2.2.branch0.bn.weight
# resnet	: repeat_2.2.branch0.bn.bias
# resnet	: repeat_2.2.branch1.0.conv.weight
# resnet	: repeat_2.2.branch1.0.bn.weight
# resnet	: repeat_2.2.branch1.0.bn.bias
# resnet	: repeat_2.2.branch1.1.conv.weight
# resnet	: repeat_2.2.branch1.1.bn.weight
# resnet	: repeat_2.2.branch1.1.bn.bias
# resnet	: repeat_2.2.branch1.2.conv.weight
# resnet	: repeat_2.2.branch1.2.bn.weight
# resnet	: repeat_2.2.branch1.2.bn.bias
# resnet	: repeat_2.2.conv2d.weight
# resnet	: repeat_2.2.conv2d.bias
# resnet	: repeat_2.3.branch0.conv.weight
# resnet	: repeat_2.3.branch0.bn.weight
# resnet	: repeat_2.3.branch0.bn.bias
# resnet	: repeat_2.3.branch1.0.conv.weight
# resnet	: repeat_2.3.branch1.0.bn.weight
# resnet	: repeat_2.3.branch1.0.bn.bias
# resnet	: repeat_2.3.branch1.1.conv.weight
# resnet	: repeat_2.3.branch1.1.bn.weight
# resnet	: repeat_2.3.branch1.1.bn.bias
# resnet	: repeat_2.3.branch1.2.conv.weight
# resnet	: repeat_2.3.branch1.2.bn.weight
# resnet	: repeat_2.3.branch1.2.bn.bias
# resnet	: repeat_2.3.conv2d.weight
# resnet	: repeat_2.3.conv2d.bias
# resnet	: repeat_2.4.branch0.conv.weight
# resnet	: repeat_2.4.branch0.bn.weight
# resnet	: repeat_2.4.branch0.bn.bias
# resnet	: repeat_2.4.branch1.0.conv.weight
# resnet	: repeat_2.4.branch1.0.bn.weight
# resnet	: repeat_2.4.branch1.0.bn.bias
# resnet	: repeat_2.4.branch1.1.conv.weight
# resnet	: repeat_2.4.branch1.1.bn.weight
# resnet	: repeat_2.4.branch1.1.bn.bias
# resnet	: repeat_2.4.branch1.2.conv.weight
# resnet	: repeat_2.4.branch1.2.bn.weight
# resnet	: repeat_2.4.branch1.2.bn.bias
# resnet	: repeat_2.4.conv2d.weight
# resnet	: repeat_2.4.conv2d.bias
# resnet	: repeat_2.5.branch0.conv.weight
# resnet	: repeat_2.5.branch0.bn.weight
# resnet	: repeat_2.5.branch0.bn.bias
# resnet	: repeat_2.5.branch1.0.conv.weight
# resnet	: repeat_2.5.branch1.0.bn.weight
# resnet	: repeat_2.5.branch1.0.bn.bias
# resnet	: repeat_2.5.branch1.1.conv.weight
# resnet	: repeat_2.5.branch1.1.bn.weight
# resnet	: repeat_2.5.branch1.1.bn.bias
# resnet	: repeat_2.5.branch1.2.conv.weight
# resnet	: repeat_2.5.branch1.2.bn.weight
# resnet	: repeat_2.5.branch1.2.bn.bias
# resnet	: repeat_2.5.conv2d.weight
# resnet	: repeat_2.5.conv2d.bias
# resnet	: repeat_2.6.branch0.conv.weight
# resnet	: repeat_2.6.branch0.bn.weight
# resnet	: repeat_2.6.branch0.bn.bias
# resnet	: repeat_2.6.branch1.0.conv.weight
# resnet	: repeat_2.6.branch1.0.bn.weight
# resnet	: repeat_2.6.branch1.0.bn.bias
# resnet	: repeat_2.6.branch1.1.conv.weight
# resnet	: repeat_2.6.branch1.1.bn.weight
# resnet	: repeat_2.6.branch1.1.bn.bias
# resnet	: repeat_2.6.branch1.2.conv.weight
# resnet	: repeat_2.6.branch1.2.bn.weight
# resnet	: repeat_2.6.branch1.2.bn.bias
# resnet	: repeat_2.6.conv2d.weight
# resnet	: repeat_2.6.conv2d.bias
# resnet	: repeat_2.7.branch0.conv.weight
# resnet	: repeat_2.7.branch0.bn.weight
# resnet	: repeat_2.7.branch0.bn.bias
# resnet	: repeat_2.7.branch1.0.conv.weight
# resnet	: repeat_2.7.branch1.0.bn.weight
# resnet	: repeat_2.7.branch1.0.bn.bias
# resnet	: repeat_2.7.branch1.1.conv.weight
# resnet	: repeat_2.7.branch1.1.bn.weight
# resnet	: repeat_2.7.branch1.1.bn.bias
# resnet	: repeat_2.7.branch1.2.conv.weight
# resnet	: repeat_2.7.branch1.2.bn.weight
# resnet	: repeat_2.7.branch1.2.bn.bias
# resnet	: repeat_2.7.conv2d.weight
# resnet	: repeat_2.7.conv2d.bias
# resnet	: repeat_2.8.branch0.conv.weight
# resnet	: repeat_2.8.branch0.bn.weight
# resnet	: repeat_2.8.branch0.bn.bias
# resnet	: repeat_2.8.branch1.0.conv.weight
# resnet	: repeat_2.8.branch1.0.bn.weight
# resnet	: repeat_2.8.branch1.0.bn.bias
# resnet	: repeat_2.8.branch1.1.conv.weight
# resnet	: repeat_2.8.branch1.1.bn.weight
# resnet	: repeat_2.8.branch1.1.bn.bias
# resnet	: repeat_2.8.branch1.2.conv.weight
# resnet	: repeat_2.8.branch1.2.bn.weight
# resnet	: repeat_2.8.branch1.2.bn.bias
# resnet	: repeat_2.8.conv2d.weight
# resnet	: repeat_2.8.conv2d.bias
# resnet	: repeat_2.9.branch0.conv.weight
# resnet	: repeat_2.9.branch0.bn.weight
# resnet	: repeat_2.9.branch0.bn.bias
# resnet	: repeat_2.9.branch1.0.conv.weight
# resnet	: repeat_2.9.branch1.0.bn.weight
# resnet	: repeat_2.9.branch1.0.bn.bias
# resnet	: repeat_2.9.branch1.1.conv.weight
# resnet	: repeat_2.9.branch1.1.bn.weight
# resnet	: repeat_2.9.branch1.1.bn.bias
# resnet	: repeat_2.9.branch1.2.conv.weight
# resnet	: repeat_2.9.branch1.2.bn.weight
# resnet	: repeat_2.9.branch1.2.bn.bias
# resnet	: repeat_2.9.conv2d.weight
# resnet	: repeat_2.9.conv2d.bias
# resnet	: mixed_7a.branch0.0.conv.weight
# resnet	: mixed_7a.branch0.0.bn.weight
# resnet	: mixed_7a.branch0.0.bn.bias
# resnet	: mixed_7a.branch0.1.conv.weight
# resnet	: mixed_7a.branch0.1.bn.weight
# resnet	: mixed_7a.branch0.1.bn.bias
# resnet	: mixed_7a.branch1.0.conv.weight
# resnet	: mixed_7a.branch1.0.bn.weight
# resnet	: mixed_7a.branch1.0.bn.bias
# resnet	: mixed_7a.branch1.1.conv.weight
# resnet	: mixed_7a.branch1.1.bn.weight
# resnet	: mixed_7a.branch1.1.bn.bias
# resnet	: mixed_7a.branch2.0.conv.weight
# resnet	: mixed_7a.branch2.0.bn.weight
# resnet	: mixed_7a.branch2.0.bn.bias
# resnet	: mixed_7a.branch2.1.conv.weight
# resnet	: mixed_7a.branch2.1.bn.weight
# resnet	: mixed_7a.branch2.1.bn.bias
# resnet	: mixed_7a.branch2.2.conv.weight
# resnet	: mixed_7a.branch2.2.bn.weight
# resnet	: mixed_7a.branch2.2.bn.bias
# resnet	: repeat_3.0.branch0.conv.weight
# resnet	: repeat_3.0.branch0.bn.weight
# resnet	: repeat_3.0.branch0.bn.bias
# resnet	: repeat_3.0.branch1.0.conv.weight
# resnet	: repeat_3.0.branch1.0.bn.weight
# resnet	: repeat_3.0.branch1.0.bn.bias
# resnet	: repeat_3.0.branch1.1.conv.weight
# resnet	: repeat_3.0.branch1.1.bn.weight
# resnet	: repeat_3.0.branch1.1.bn.bias
# resnet	: repeat_3.0.branch1.2.conv.weight
# resnet	: repeat_3.0.branch1.2.bn.weight
# resnet	: repeat_3.0.branch1.2.bn.bias
# resnet	: repeat_3.0.conv2d.weight
# resnet	: repeat_3.0.conv2d.bias
# resnet	: repeat_3.1.branch0.conv.weight
# resnet	: repeat_3.1.branch0.bn.weight
# resnet	: repeat_3.1.branch0.bn.bias
# resnet	: repeat_3.1.branch1.0.conv.weight
# resnet	: repeat_3.1.branch1.0.bn.weight
# resnet	: repeat_3.1.branch1.0.bn.bias
# resnet	: repeat_3.1.branch1.1.conv.weight
# resnet	: repeat_3.1.branch1.1.bn.weight
# resnet	: repeat_3.1.branch1.1.bn.bias
# resnet	: repeat_3.1.branch1.2.conv.weight
# resnet	: repeat_3.1.branch1.2.bn.weight
# resnet	: repeat_3.1.branch1.2.bn.bias
# resnet	: repeat_3.1.conv2d.weight
# resnet	: repeat_3.1.conv2d.bias
# resnet	: repeat_3.2.branch0.conv.weight
# resnet	: repeat_3.2.branch0.bn.weight
# resnet	: repeat_3.2.branch0.bn.bias
# resnet	: repeat_3.2.branch1.0.conv.weight
# resnet	: repeat_3.2.branch1.0.bn.weight
# resnet	: repeat_3.2.branch1.0.bn.bias
# resnet	: repeat_3.2.branch1.1.conv.weight
# resnet	: repeat_3.2.branch1.1.bn.weight
# resnet	: repeat_3.2.branch1.1.bn.bias
# resnet	: repeat_3.2.branch1.2.conv.weight
# resnet	: repeat_3.2.branch1.2.bn.weight
# resnet	: repeat_3.2.branch1.2.bn.bias
# resnet	: repeat_3.2.conv2d.weight
# resnet	: repeat_3.2.conv2d.bias
# resnet	: repeat_3.3.branch0.conv.weight
# resnet	: repeat_3.3.branch0.bn.weight
# resnet	: repeat_3.3.branch0.bn.bias
# resnet	: repeat_3.3.branch1.0.conv.weight
# resnet	: repeat_3.3.branch1.0.bn.weight
# resnet	: repeat_3.3.branch1.0.bn.bias
# resnet	: repeat_3.3.branch1.1.conv.weight
# resnet	: repeat_3.3.branch1.1.bn.weight
# resnet	: repeat_3.3.branch1.1.bn.bias
# resnet	: repeat_3.3.branch1.2.conv.weight
# resnet	: repeat_3.3.branch1.2.bn.weight
# resnet	: repeat_3.3.branch1.2.bn.bias
# resnet	: repeat_3.3.conv2d.weight
# resnet	: repeat_3.3.conv2d.bias
# resnet	: repeat_3.4.branch0.conv.weight
# resnet	: repeat_3.4.branch0.bn.weight
# resnet	: repeat_3.4.branch0.bn.bias
# resnet	: repeat_3.4.branch1.0.conv.weight
# resnet	: repeat_3.4.branch1.0.bn.weight
# resnet	: repeat_3.4.branch1.0.bn.bias
# resnet	: repeat_3.4.branch1.1.conv.weight
# resnet	: repeat_3.4.branch1.1.bn.weight
# resnet	: repeat_3.4.branch1.1.bn.bias
# resnet	: repeat_3.4.branch1.2.conv.weight
# resnet	: repeat_3.4.branch1.2.bn.weight
# resnet	: repeat_3.4.branch1.2.bn.bias
# resnet	: repeat_3.4.conv2d.weight
# resnet	: repeat_3.4.conv2d.bias
# resnet	: block8.branch0.conv.weight
# resnet	: block8.branch0.bn.weight
# resnet	: block8.branch0.bn.bias
# resnet	: block8.branch1.0.conv.weight
# resnet	: block8.branch1.0.bn.weight
# resnet	: block8.branch1.0.bn.bias
# resnet	: block8.branch1.1.conv.weight
# resnet	: block8.branch1.1.bn.weight
# resnet	: block8.branch1.1.bn.bias
# resnet	: block8.branch1.2.conv.weight
# resnet	: block8.branch1.2.bn.weight
# resnet	: block8.branch1.2.bn.bias
# resnet	: block8.conv2d.weight
# resnet	: block8.conv2d.bias
# resnet	: last_linear.weight
# resnet	: last_bn.weight
# resnet	: last_bn.bias
# resnet	: logits.weight
# resnet	: logits.bias

# %%
lr = 0.00001
milestones = [12, 24, 36, 48]
weight_decay = 0.0000

# ***** *****
# Set an optimizer, scheduler, etc.
net_params = resnet.parameters()
optimizer = optim.Adam(net_params, lr = lr, weight_decay = weight_decay)
scheduler = lr_scheduler.MultiStepLR(optimizer, milestones = milestones, gamma = 0.1)

# ***** *****

# Define loss and evaluation functions
loss_fn = torch.nn.CrossEntropyLoss()
metrics = {
    'fps': training.BatchTimer(),
    'acc': training.accuracy
}

# %%
# Start fine-tuning resnset
writer = SummaryWriter()
writer.iteration, writer.interval = 0, 10

# ***** ***** print initial evaluation output

print('\n\nInitial')
print('-' * 8)

resnet.eval()

training.run_training(resnet, loss_fn, test_loader,
                     batch_metrics=metrics, show_running=True, device=device,
                     writer=writer)

# ***** ***** training mode

for epoch in range(epochs):
    
    print('\nEpoch {}/{}'.format(epoch + 1, epochs))
    print('-' * 10)

    resnet.train()
    
    for layer in resnet.modules():
        if isinstance(layer,torch.nn.modules.batchnorm.BatchNorm2d):
            #print(layer)
            layer.eval()
    
    training.run_training(resnet, loss_fn, train_loader, optimizer, scheduler, #training
                          batch_metrics=metrics, show_running=True, device=device,
                          writer=writer)
    
    # ***** evaluation mode

    resnet.eval()

    training.run_training(resnet, loss_fn, test_loader,
                         batch_metrics=metrics, show_running=True, device=device,
                         writer=writer)

# ***** *****

writer.close()
# Out:
# Initial
# --------
# Test |   117/117  | loss:    4.5356 | fps:  225.7105 | acc:    0.3101
#
# Epoch 1/40
# ----------
# Train |   383/383  | loss:    0.5722 | fps:   77.1816 | acc:    0.8986
# Test |   117/117  | loss:    4.6298 | fps:  579.2845 | acc:    0.3178
#
# Epoch 2/40
# ----------
# Train |   383/383  | loss:    0.4296 | fps:  213.3789 | acc:    0.9254
# Test |   117/117  | loss:    4.5314 | fps:  594.4390 | acc:    0.3331
#
# Epoch 3/40
# ----------
# Train |   383/383  | loss:    0.3424 | fps:  214.4988 | acc:    0.9406
# Test |   117/117  | loss:    4.4856 | fps:  580.9926 | acc:    0.3403
#
# Epoch 4/40
# ----------
# Train |   383/383  | loss:    0.2825 | fps:  208.6649 | acc:    0.9540
# Test |   117/117  | loss:    4.4745 | fps:  563.4277 | acc:    0.3379
#
# Epoch 5/40
# ----------
# Train |   383/383  | loss:    0.2227 | fps:  213.1296 | acc:    0.9662
# Test |   117/117  | loss:    4.3984 | fps:  562.0198 | acc:    0.3528
#
# Epoch 6/40
# ----------
# Train |   383/383  | loss:    0.1866 | fps:  197.5925 | acc:    0.9735
# Test |   117/117  | loss:    4.4841 | fps:  472.7222 | acc:    0.3488
#
# Epoch 7/40
# ----------
# Train |   383/383  | loss:    0.1542 | fps:  145.5529 | acc:    0.9788
# Test |   117/117  | loss:    4.5415 | fps:  474.7476 | acc:    0.3558
#
# Epoch 8/40
# ----------
# Train |   383/383  | loss:    0.1202 | fps:  145.5131 | acc:    0.9878
# Test |   117/117  | loss:    4.5488 | fps:  476.4140 | acc:    0.3547
#
# Epoch 9/40
# ----------
# Train |   383/383  | loss:    0.1075 | fps:  145.3225 | acc:    0.9894
# Test |   117/117  | loss:    4.4941 | fps:  477.3743 | acc:    0.3592
#
# Epoch 10/40
# ----------
# Train |   383/383  | loss:    0.0902 | fps:  145.5575 | acc:    0.9931
# Test |   117/117  | loss:    4.4730 | fps:  475.6794 | acc:    0.3646
#
# Epoch 11/40
# ----------
# Train |   383/383  | loss:    0.0720 | fps:  145.5304 | acc:    0.9949
# Test |   117/117  | loss:    4.4251 | fps:  476.7657 | acc:    0.3657
#
# Epoch 12/40
# ----------
# Train |   383/383  | loss:    0.0628 | fps:  143.8145 | acc:    0.9972
# Test |   117/117  | loss:    4.4761 | fps:  471.1998 | acc:    0.3662
#
# Epoch 13/40
# ----------
# Train |   383/383  | loss:    0.0395 | fps:  145.4107 | acc:    0.9990
# Test |   117/117  | loss:    4.3637 | fps:  475.7825 | acc:    0.3713
#
# Epoch 14/40
# ----------
# Train |   383/383  | loss:    0.0334 | fps:  145.4008 | acc:    0.9999
# Test |   117/117  | loss:    4.3224 | fps:  478.1219 | acc:    0.3755
#
# Epoch 15/40
# ----------
# Train |   383/383  | loss:    0.0325 | fps:  145.7020 | acc:    0.9998
# Test |   117/117  | loss:    4.3654 | fps:  478.7934 | acc:    0.3723
#
# Epoch 16/40
# ----------
# Train |   383/383  | loss:    0.0310 | fps:  145.5672 | acc:    0.9998
# Test |   117/117  | loss:    4.3331 | fps:  476.8651 | acc:    0.3766
#
# Epoch 17/40
# ----------
# Train |   383/383  | loss:    0.0302 | fps:  145.2181 | acc:    0.9998
# Test |   117/117  | loss:    4.3416 | fps:  473.2333 | acc:    0.3753
#
# Epoch 18/40
# ----------
# Train |   383/383  | loss:    0.0290 | fps:  141.0742 | acc:    0.9999
# Test |   117/117  | loss:    4.3397 | fps:  337.1259 | acc:    0.3787
#
# Epoch 19/40
# ----------
# Train |   383/383  | loss:    0.0282 | fps:   92.4529 | acc:    1.0000
# Test |   117/117  | loss:    4.3152 | fps:  336.4200 | acc:    0.3790
#
# Epoch 20/40
# ----------
# Train |   383/383  | loss:    0.0277 | fps:   92.3230 | acc:    1.0000
# Test |   117/117  | loss:    4.3241 | fps:  336.6672 | acc:    0.3782
#
# Epoch 21/40
# ----------
# Train |   383/383  | loss:    0.0266 | fps:   95.2060 | acc:    1.0000
# Test |   117/117  | loss:    4.3034 | fps:  354.3325 | acc:    0.3782
#
# Epoch 22/40
# ----------
# Train |   383/383  | loss:    0.0260 | fps:   99.9288 | acc:    1.0000
# Test |   117/117  | loss:    4.3227 | fps:  366.9683 | acc:    0.3798
#
# Epoch 23/40
# ----------
# Train |   383/383  | loss:    0.0253 | fps:  101.2046 | acc:    1.0000
# Test |   117/117  | loss:    4.3157 | fps:  367.2316 | acc:    0.3782
#
# Epoch 24/40
# ----------
# Train |   383/383  | loss:    0.0241 | fps:  101.1237 | acc:    1.0000
# Test |   117/117  | loss:    4.3071 | fps:  363.8376 | acc:    0.3806
#
# Epoch 25/40
# ----------
# Train |   383/383  | loss:    0.0238 | fps:  101.1779 | acc:    1.0000
# Test |   117/117  | loss:    4.3159 | fps:  367.6361 | acc:    0.3811
#
# Epoch 26/40
# ----------
# Train |   383/383  | loss:    0.0230 | fps:  101.0858 | acc:    0.9999
# Test |   117/117  | loss:    4.2983 | fps:  366.7795 | acc:    0.3766
#
# Epoch 27/40
# ----------
# Train |   383/383  | loss:    0.0228 | fps:  100.6740 | acc:    1.0000
# Test |   117/117  | loss:    4.3016 | fps:  367.7197 | acc:    0.3790
#
# Epoch 28/40
# ----------
# Train |   383/383  | loss:    0.0229 | fps:  101.6776 | acc:    1.0000
# Test |   117/117  | loss:    4.3058 | fps:  368.7413 | acc:    0.3761
#
# Epoch 29/40
# ----------
# Train |   383/383  | loss:    0.0229 | fps:  101.4872 | acc:    1.0000
# Test |   117/117  | loss:    4.3103 | fps:  368.7354 | acc:    0.3745
#
# Epoch 30/40
# ----------
# Train |   383/383  | loss:    0.0226 | fps:  101.6761 | acc:    1.0000
# Test |   117/117  | loss:    4.3136 | fps:  368.5351 | acc:    0.3787
#
# Epoch 31/40
# ----------
# Train |   383/383  | loss:    0.0227 | fps:  101.1687 | acc:    1.0000
# Test |   117/117  | loss:    4.3039 | fps:  364.0458 | acc:    0.3806
#
# Epoch 32/40
# ----------
# Train |   383/383  | loss:    0.0224 | fps:  101.1864 | acc:    1.0000
# Test |   117/117  | loss:    4.3119 | fps:  368.0511 | acc:    0.3795
#
# Epoch 33/40
# ----------
# Train |   383/383  | loss:    0.0226 | fps:  100.7869 | acc:    1.0000
# Test |   117/117  | loss:    4.3023 | fps:  365.5584 | acc:    0.3787
#
# Epoch 34/40
# ----------
# Train |   383/383  | loss:    0.0226 | fps:   99.0083 | acc:    1.0000
# Test |   117/117  | loss:    4.3021 | fps:  364.8455 | acc:    0.3801
#
# Epoch 35/40
# ----------
# Train |   383/383  | loss:    0.0221 | fps:  100.2430 | acc:    1.0000
# Test |   117/117  | loss:    4.3035 | fps:  363.9690 | acc:    0.3798
#
# Epoch 36/40
# ----------
# Train |   383/383  | loss:    0.0222 | fps:  100.2468 | acc:    1.0000
# Test |   117/117  | loss:    4.2914 | fps:  365.4910 | acc:    0.3822
#
# Epoch 37/40
# ----------
# Train |   383/383  | loss:    0.0220 | fps:  100.8286 | acc:    1.0000
# Test |   117/117  | loss:    4.3070 | fps:  363.8893 | acc:    0.3787
#
# Epoch 38/40
# ----------
# Train |   383/383  | loss:    0.0219 | fps:  100.5496 | acc:    1.0000
# Test |   117/117  | loss:    4.2943 | fps:  362.5528 | acc:    0.3819
#
# Epoch 39/40
# ----------
# Train |   383/383  | loss:    0.0219 | fps:  100.3957 | acc:    1.0000
# Test |   117/117  | loss:    4.3016 | fps:  364.4051 | acc:    0.3798
#
# Epoch 40/40
# ----------
# Train |   383/383  | loss:    0.0218 | fps:  100.3557 | acc:    1.0000
# Test |   117/117  | loss:    4.2943 | fps:  363.5240 | acc:    0.3803
